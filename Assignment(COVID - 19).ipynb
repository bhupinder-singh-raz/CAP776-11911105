# %% [markdown]
# # COVID - 19

# %% [markdown]
# # 1. World wide Confirmed Cases

# %%
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.offsetbox import OffsetImage,AnnotationBbox
df=pd.read_excel('covid_world.xlsx')
df1=df

# %%
c=df1.head(12)

# %%
confirmed=c[["Country","Confirmed"]]
values=c["Confirmed"].tolist()
country=c["Country"].tolist()

# %%
confirmed
# Out:
#            Country  Confirmed
# 0    United States     676676
# 1            Spain     185309
# 2            Italy     168941
# 3          Germany     137698
# 4           France     108847
# 5   United Kingdom     103093
# 6            China      82367
# 7             Iran      77995
# 8           Brazil      30683
# 9           Canada      30106
# 10         Austria      14475
# 11           India      13387

# %%
plt.figure(figsize=(25,15))


#Function (image path)
def get_flag(name):
    path = "{}.png".format(name.title())
    im = plt.imread(path)
    return im

def offset_image(coord, name, ax):
    img = get_flag(name)
    xaxis=values[i]+20000
    im = OffsetImage(img, zoom=0.65)
    im.image.axes = ax

    ab = AnnotationBbox(im, (xaxis,i),  xybox=(0., 0.), frameon=False, xycoords='data',  boxcoords="offset points", pad=0)

    ax.add_artist(ab)
    
ax=plt.subplot()

#confirmed.sort_values('Confirmed',inplace=True)


#COLORS
clrs = [(0.2, 0.4, 0.6, 0.6) if (x < max(values)) else '#E74C3C' for x in values ]
plt.barh(confirmed['Country'],confirmed['Confirmed'],color=clrs,edgecolor='blue')

#LABELING
plt.xlabel('No of Confirmed Cases',fontsize=30,color='#3498DB')
plt.ylabel('Countries',fontsize=30,color='#3498DB')

#X-axis and Y-axis actual values
plt.yticks(country,fontsize=15)
plt.xticks([10000,100000,200000,300000,400000,500000,600000,700000,800000],fontsize=15)

#Giving Title to the graph
plt.title('World wide cases till 17 April',fontsize=30,pad=45 )

for i, c in enumerate(country):
    offset_image(i, c, ax)
    
plt.show()

# %% [markdown]
# # 2. India Covid-19 Cases Statewise

# %%
df=pd.read_excel('CovidStateWise.xlsx')
df2=df

# %%
df2
# Out:
#                           State  Confirmed  Recovered  Deaths  Active  \
# 0                   Maharashtra       1364        125      98    1141
# 1                    Tamil Nadu        834         27       8     799
# 2                         Delhi        720         25      12     683
# 3                     Telangana        471         45      12     414
# 4                     Rajasthan        489         60       3     426
# 5                        Kerala        357         97       2     258
# 6                 Uttar Pradesh        410         31       4     375
# 7                Andhra Pradesh        365         10       5     350
# 8                Madhya Pradesh        412         25      33     354
# 9                     Karnataka        197         30       6     161
# 10                      Gujarat        308         30      19     259
# 11                      Haryana        170         32       2     136
# 12            Jammu and Kashmir        184          6       4     174
# 13                       Punjab        130         18      10     102
# 14                  West Bengal        116         16       5      95
# 15                       Odisha         48          2       1      45
# 16                        Bihar         60         15       1      44
# 17                  Uttarakhand         35          5       0      30
# 18                        Assam         29          0       1      28
# 19                   Chandigarh         18          7       0      11
# 20             Himachal Pradesh         28          2       2      24
# 21                       Ladakh         15         11       0       4
# 22  Andaman and Nicobar Islands         11         10       0       1
# 23                 Chhattisgarh         18          9       0       9
# 24                          Goa          7          1       0       6
# 25                   Puducherry          5          1       0       4
# 26                    Jharkhand         14          0       1      13
# 27                      Manipur          2          1       0       1
# 28                      Mizoram          1          0       0       1
# 29            Arunachal Pradesh          1          0       0       1
# 30       Dadra and Nagar Haveli          1          0       0       1
# 31                      Tripura          1          0       0       1
# 32                Daman and Diu          0          0       0       0
# 33                  Lakshadweep          0          0       0       0
# 34                    Meghalaya          0          0       0       0
# 35                     Nagaland          0          0       0       0
# 36                       Sikkim          0          0       0       0
#
#    State_code  Delta_Confirmed  Delta_Recovered  Delta_Deaths
# 0          MH                0                0             1
# 1          TN                0                0             0
# 2          DL                0                0             0
# 3          TG                0                0             0
# 4          RJ               26                0             0
# 5          KL                0                0             0
# 6          UP                0                0             0
# 7          AP                2                0             0
# 8          MP                1                0             0
# 9          KA                0                0             0
# 10         GJ               46                4             1
# 11         HR                0                0             0
# 12         JK                0                0             0
# 13         PB                0                0             0
# 14         WB               13                0             0
# 15         OR                0                0             0
# 16         BR                2                0             0
# 17         UT                0                0             0
# 18         AS                0                0             1
# 19         CH                0                0             0
# 20         HP                0                0             0
# 21         LA                1                1             0
# 22         AN                0                0             0
# 23         CT                0                0             0
# 24         GA                0                1             0
# 25         PY                0                0             0
# 26         JH                1                0             0
# 27         MN                0                0             0
# 28         MZ                0                0             0
# 29         AR                0                0             0
# 30         DN                0                0             0
# 31         TR                0                0             0
# 32         DD                0                0             0
# 33         LD                0                0             0
# 34         ML                0                0             0
# 35         NL                0                0             0
# 36         SK                0                0             0

# %%
confirmed=df2["Confirmed"].tolist()

plt.figure(figsize=(25,25))

def value(coord, name, ax):
    xaxis=confirmed[i]
    #print(xaxis)
    plt.text(xaxis + 10 , i - .2 , xaxis , fontsize=20)

plt.barh(df2['State'],df2['Confirmed'],color='#F4D03F',label='Confirmed',edgecolor='blue')
plt.barh(df2['State'],df2['Recovered'],color='#52BE80',label='Recoverd')
plt.barh(df2['State'],df2['Deaths'],color='#E74C3C',label='Deaths')

plt.title('India Covid-19 StateWise Cases till 12 April',fontsize=30,pad=45 )
plt.ylabel('States',fontsize=40,color='#3498DB')
plt.xlabel('Total No. of Cases',fontsize=40,color='#3498DB')

plt.yticks(df2['State'],fontsize=20)
plt.xticks([0,200,400,600,800,1200,1400],fontsize=20)

plt.legend(fontsize=20)


for i, c in enumerate(df2['State']):
    value(i,c,ax)

plt.show()

# %% [markdown]
# # 3. India Covid-19 Cases AgeWise

# %%
import pandas as pd
from matplotlib import pyplot as plt

df=pd.read_csv('AgeGroupDetails.csv')
df3=df.head(9)

# %%
df3
# Out:
#    Sno AgeGroup  TotalCases Percentage
# 0    1      0-9          22      3.18%
# 1    2    10-19          27      3.90%
# 2    3    20-29         172     24.86%
# 3    4    30-39         146     21.10%
# 4    5    40-49         112     16.18%
# 5    6    50-59          77     11.13%
# 6    7    60-69          89     12.86%
# 7    8    70-79          28      4.05%
# 8    9     >=80          10      1.45%

# %%
plt.figure(figsize=(9,8))

colors = ['#1D8348','#2ECC63','#4CFD8F','#F7DC6F','#F4D03F','#F1C40F','#FD8A4C','#E74C3C','#A93226']
labels = ['over 80s','Age (0 - 9)','Age (10 - 19)' , ' Age (70 - 79)' ,'Age (50 - 59)' ,'Age (60 - 69)' ,'Age (40 - 49)','Age (30 - 39)','Age (20 - 29)']
explode = (0.2,0, 0, 0 , 0 , 0 , 0 , 0 , 0.1)

Tc = df3['TotalCases'].sort_values()
plt.pie(Tc,explode=explode,labels=labels,colors=colors, autopct='%1.1f%%', shadow=True)

plt.title('India Covid-19 Cases AgeWise',fontsize=28,pad=42 )
#plt.axis('equal')

plt.show()
